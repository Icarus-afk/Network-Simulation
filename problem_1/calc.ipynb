# %%
import  traceanalyzer as tr
#end-to-end delay
eedelay1=tr.Eedelay('p1.tr','63')
eedelay2=tr.Eedelay('p1.tr','41')
eedelay1.plot()
eedelay2.plot()
#getting data
time=eedelay2.time_array
eedelay=eedelay2.eedelay_array
idx=0
for instant in time:
    print(instant,' ',eedelay[idx]) 
    idx+=1
# Out:
# 0   0
